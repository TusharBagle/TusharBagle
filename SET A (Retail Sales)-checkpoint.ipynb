# %% [markdown]
# # Import all Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Data

# %%
Sales_DF = pd.read_csv("D:\OneDrive\Desktop\Interview Prepe\Practical Exam\Retail Sales\Sales.csv")
Product_DF = pd.read_csv("D:\OneDrive\Desktop\Interview Prepe\Practical Exam\Retail Sales\Product.csv")

Sales_DF
# Out:
#     sale_id month product_id region  quantity  unit_price
# 0         1   Jan         P1  North        12          50
# 1         2   Jan         P2  South        20          10
# 2         3   Jan         P3  North         3         500
# 3         4   Jan         P4   West         2         800
# 4         5   Feb         P1  South        15          50
# 5         6   Feb         P2   West        30          10
# 6         7   Feb         P3  North         4         500
# 7         8   Feb         P4  South         3         800
# 8         9   Mar         P1   West        10          50
# 9        10   Mar         P2  North        25          10
# 10       11   Mar         P3  South         5         500
# 11       12   Mar         P4   West         4         800
# 12       12   Mar         P4   West         4         800

# %%
Product_DF
# Out:
#   product_id   product     category
# 0         P1  Notebook   Stationery
# 1         P2       Pen   Stationery
# 2         P3     Mouse  Electronics
# 3         P4  Keyboard  Electronics

# %% [markdown]
# # Check Data Types

# %%
print(Sales_DF.dtypes)
print("\n")
print(Product_DF.dtypes)
# Out:
# sale_id        int64
# month         object
# product_id    object
# region        object
# quantity       int64
# unit_price     int64
# dtype: object
#
#
# product_id    object
# product       object
# category      object
# dtype: object

# %% [markdown]
# # Remove Exact Duplicates

# %%
print(f"Rows before remove Duplicates : {len(Sales_DF)}")
Remove_Duplicate = Sales_DF.drop_duplicates()
print(f"Rows before remove Duplicates : {len(Remove_Duplicate)}")
# Out:
# Rows before remove Duplicates : 13
# Rows before remove Duplicates : 12

# %% [markdown]
# # Merge Sales & Product with Product ID

# %%
Merged = Remove_Duplicate.merge(Product_DF , on = "product_id" , how = "left")
Merged
# Out:
#     sale_id month product_id region  quantity  unit_price   product  \
# 0         1   Jan         P1  North        12          50  Notebook
# 1         2   Jan         P2  South        20          10       Pen
# 2         3   Jan         P3  North         3         500     Mouse
# 3         4   Jan         P4   West         2         800  Keyboard
# 4         5   Feb         P1  South        15          50  Notebook
# 5         6   Feb         P2   West        30          10       Pen
# 6         7   Feb         P3  North         4         500     Mouse
# 7         8   Feb         P4  South         3         800  Keyboard
# 8         9   Mar         P1   West        10          50  Notebook
# 9        10   Mar         P2  North        25          10       Pen
# 10       11   Mar         P3  South         5         500     Mouse
# 11       12   Mar         P4   West         4         800  Keyboard
#
#        category
# 0    Stationery
# 1    Stationery
# 2   Electronics
# 3   Electronics
# 4    Stationery
# 5    Stationery
# 6   Electronics
# 7   Electronics
# 8    Stationery
# 9    Stationery
# 10  Electronics
# 11  Electronics

# %% [markdown]
# # Calculate Revenue

# %%
Merged["Revenue"] = Merged["unit_price"] * Merged["quantity"]
Merged
# Out:
#     sale_id month product_id region  quantity  unit_price   product  \
# 0         1   Jan         P1  North        12          50  Notebook
# 1         2   Jan         P2  South        20          10       Pen
# 2         3   Jan         P3  North         3         500     Mouse
# 3         4   Jan         P4   West         2         800  Keyboard
# 4         5   Feb         P1  South        15          50  Notebook
# 5         6   Feb         P2   West        30          10       Pen
# 6         7   Feb         P3  North         4         500     Mouse
# 7         8   Feb         P4  South         3         800  Keyboard
# 8         9   Mar         P1   West        10          50  Notebook
# 9        10   Mar         P2  North        25          10       Pen
# 10       11   Mar         P3  South         5         500     Mouse
# 11       12   Mar         P4   West         4         800  Keyboard
#
#        category  Revenue
# 0    Stationery      600
# 1    Stationery      200
# 2   Electronics     1500
# 3   Electronics     1600
# 4    Stationery      750
# 5    Stationery      300
# 6   Electronics     2000
# 7   Electronics     2400
# 8    Stationery      500
# 9    Stationery      250
# 10  Electronics     2500
# 11  Electronics     3200

# %% [markdown]
# # Group Summary

# %%
Category_Summary = Merged.groupby("category" , as_index = False)["Revenue"].sum().sort_values("Revenue", ascending = False)
Category_Summary
# Out:
#       category  Revenue
# 0  Electronics    13200
# 1   Stationery     2600

# %% [markdown]
# # Highest Revenue Product

# %%
Highest_Product = Category_Summary.iloc[0]
Total_Revnue = Merged["Revenue"].sum()

Highest_Product_PCT = Highest_Product["Revenue"] / Total_Revnue * 100

print(f"Highest Product Category : {Highest_Product["category"]}")
print(f"Highest Product Category (in Parcentage) : {round(Highest_Product_PCT , 2)} %")
# Out:
# Highest Product Category : Electronics
# Highest Product Category (in Parcentage) : 83.54 %

# %% [markdown]
# # Monthly Revenue

# %%
Monthly_Revenue = pd.pivot_table(Merged , values = "Revenue" , index = "month" , aggfunc = "sum")
Monthly_Revenue
# Out:
#        Revenue
# month
# Feb       5450
# Jan       3900
# Mar       6450

# %% [markdown]
# # Regional Revenue

# %%
Regional_revenue = Merged.groupby("region")["Revenue"].sum().sort_values(ascending = False)
Regional_revenue
# Out:
# region
# South    5850
# West     5600
# North    4350
# Name: Revenue, dtype: int64

# %% [markdown]
# # Monthly Revenue Chart (Bar)

# %%
month_order = ["Jan" , "Feb" , "Mar"]

Monthly_Revenue.index = month_order


plt.figure(figsize = (8 , 5))

Monthly_Revenue.plot(kind = "bar" , color = "darkblue")

plt.title("Monthly Revenue" , fontsize = 18 , fontweight = "bold")
plt.xlabel("Month" , fontsize = 14)
plt.ylabel("Revenue" , fontsize = 14)

plt.show()


plt.savefig(
    "outputs/python_chart.png",
    dpi=150
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 17
#      12 plt.ylabel("Revenue" , fontsize = 14)
#      14 plt.show()
# ---> 17 plt.savefig(
#      18     "outputs/python_chart.png",
#      19     dpi=150
#      20 )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2566, in Image.save(self, fp, format, **params)
#    2564         fp = builtins.open(filename, "r+b")
#    2565     else:
# -> 2566         fp = builtins.open(filename, "w+b")
#    2567 else:
#    2568     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/python_chart.png'

# %% [markdown]
# # Export Clean Data

# %%
import os

os.makedirs("output" , exist_ok = True)

Merged.to_csv("output/clean_data.csv" , index = "False")

# %% [markdown]
# # Export Category Summary

# %%
import os

os.makedirs("output" , exist_ok = True)
Regional_revenue.to_csv("output/python_summary.csv" , index = False)

# %% [markdown]
# # Final Summary

# %%
Revenue_Per_Transection = round(Merged["Revenue"].sum() / Merged["sale_id"].nunique() , 2)

print("--------------------------------------------")
print("               Final Summary                ")
print("--------------------------------------------")

print(f"\nTotal Revenue : {Merged["Revenue"].sum()}")
print(f"Total Quantity : {Merged["quantity"].sum()}")
print(f"Revenue Per Transection : {Revenue_Per_Transection}")

print("\n--------------------------------------------")

# %%
print("Python Analysis Completed Successfully !...")
